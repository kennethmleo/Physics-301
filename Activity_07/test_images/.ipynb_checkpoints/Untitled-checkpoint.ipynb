# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
import glob

# %%
f = sorted(glob.glob('*.jpeg'))
f
# Out:
# ['JPEG 01.jpeg',
#  'JPEG 02.jpeg',
#  'JPEG 03.jpeg',
#  'JPEG 04.jpeg',
#  'JPEG 05.jpeg',
#  'JPEG 06.jpeg',
#  'JPEG 07.jpeg',
#  'JPEG 08.jpeg']

# %%
for i in f:
    plt.imshow(cv2.imread(i, cv2.IMREAD_GRAYSCALE)[500:2500,1500:3500])
    plt.show()
